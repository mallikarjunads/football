# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
a=pd.read_csv("project4.csv")

# %%
a.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# ...

# %%
a.isna().sum()
# Out:
# ID                            0
# Name                          0
# Age                           0
# Nationality                   0
# Overall                       0
# Potential                     0
# Club                        241
# Value                       252
# Wage                          0
# Preferred Foot                0
# International Reputation     48
# Skill Moves                  48
# Position                      0
# Joined                        0
# Contract Valid Until        289
# Height                        0
# Weight                        0
# Release Clause                0
# dtype: int64

# %%
a.shape
# Out:
# (18207, 18)

# %%
a=a.dropna()

# %%
a
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
a.reset_index()
# Out:
#        index      ID                Name  Age Nationality  Overall  Potential  \
# 0          0  158023            L. Messi   31   Argentina       94         94
# 1          1   20801   Cristiano Ronaldo   33    Portugal       94         94
# 2          2  190871           Neymar Jr   26      Brazil       92         93
# 3          3  193080              De Gea   27       Spain       91         93
# 4          4  192985        K. De Bruyne   27     Belgium       91         92
# ...      ...     ...                 ...  ...         ...      ...        ...
# 17902  18202  238813        J. Lundstram   19     England       47         65
# 17903  18203  243165  N. Christoffersson   19      Sweden       47         63
# 17904  18204  241638           B. Worman   16     England       47         67
# 17905  18205  246268      D. Walker-Rice   17     England       47         66
# 17906  18206  246269           G. Nugent   16     England       46         66
#
# ...

# %%
a.sample(6)
# Out:
#            ID          Name  Age  Nationality  Overall  Potential  \
# 5026   219466     B. Meling   23       Norway       70         75
# 8442   227766      L. Dvali   23      Georgia       67         73
# 13734  243395     C. Essers   21  Netherlands       62         67
# 532    166706     M. Škrtel   33     Slovakia       80         80
# 13121  190481    M. Solheim   30       Norway       62         62
# 241    216267  A. Robertson   24     Scotland       82         87
#
#                   Club    Value  Wage Preferred Foot  \
# 5026      Rosenborg BK   2000.0   4.0           Left
# 8442    Pogoń Szczecin    900.0   2.0          Right
# 13734  Fortuna Sittard    350.0   1.0          Right
# 532      Fenerbahçe SK   6000.0  68.0          Right
# 13121      Hammarby IF    220.0   1.0          Right
# 241          Liverpool  24500.0  98.0           Left
#
#        International Reputation  Skill Moves Position  Joined  \
# ...

# %%
b=a["Nationality"].value_counts().head()

# %%
b
# Out:
# Nationality
# England      1655
# Germany      1195
# Spain        1071
# Argentina     935
# France        910
# Name: count, dtype: int64

# %%
sns.barplot(x=b.index,y=b.values)
sns.lineplot(x=b.index,y=b.values)
# Out:
# <Axes: xlabel='Nationality'>

# %%
c=a["Age"].sort_values(ascending=0)

# %%
c
# Out:
# 4741     45
# 10545    42
# 7225     41
# 15426    41
# 4187     40
#          ..
# 17881    16
# 18162    16
# 17887    16
# 18003    16
# 18206    16
# Name: Age, Length: 17907, dtype: int64

# %%
a.loc[c.index]
# Out:
#            ID          Name  Age Nationality  Overall  Potential  \
# 4741   140029      O. Pérez   45      Mexico       71         71
# 10545  140183   S. Narazaki   42       Japan       65         65
# 7225   142998      C. Muñoz   41   Argentina       68         68
# 15426   18745      M. Tyler   41     England       59         59
# 4187   156483  C. Lucchetti   40   Argentina       71         71
# ...       ...           ...  ...         ...      ...        ...
# 17881  242165      R. Hauge   16      Norway       52         67
# 18162  243866  T. Gundelund   16     Denmark       48         66
# 17887  246009      M. Tilio   16   Australia       52         69
# 18003  239594  J. Imbrechts   16      Sweden       51         72
# 18206  246269     G. Nugent   16     England       46         66
#
#                                Club  Value  Wage Preferred Foot  \
# 4741                        Pachuca  160.0   8.0          Right
# ...

# %%
print("O. Pérez is the old player in fifa world cup")
# Out:
# O. Pérez is the old player in fifa world cup

# %%
d=a["Age"].sort_values()

# %%
d
# Out:
# 18206    16
# 18044    16
# 16254    16
# 16418    16
# 17776    16
#          ..
# 41       40
# 7225     41
# 15426    41
# 10545    42
# 4741     45
# Name: Age, Length: 17907, dtype: int64

# %%
a.loc[d.index]
# Out:
#            ID            Name  Age  Nationality  Overall  Potential  \
# 18206  246269       G. Nugent   16      England       46         66
# 18044  246109         K. Lara   16     Colombia       50         74
# 16254  244728       S. Steijn   16  Netherlands       58         72
# 16418  242531     J. Kitolano   16       Norway       57         75
# 17776  244553  M. Köstenbauer   16      Austria       52         74
# ...       ...             ...  ...          ...      ...        ...
# 41       1179       G. Buffon   40        Italy       88         88
# 7225   142998        C. Muñoz   41    Argentina       68         68
# 15426   18745        M. Tyler   41      England       59         59
# 10545  140183     S. Narazaki   42        Japan       65         65
# 4741   140029        O. Pérez   45       Mexico       71         71
#
#                                Club   Value  Wage Preferred Foot  \
# 18206               Tranmere Rovers    60.0   1.0          Right
# ...

# %%
print("16 is the youngest age in fifa world cup")
# Out:
# 16 is the youngest age in fifa world cup

# %%
e=a["Club"].value_counts().head(5)

# %%
e
# Out:
# Club
# FC Barcelona               33
# Southampton                33
# Cardiff City               33
# TSG 1899 Hoffenheim        33
# Wolverhampton Wanderers    33
# Name: count, dtype: int64

# %%
plt.bar(e.index,e.values)
plt.xticks(rotation="vertical")
plt.bar_label(plt.gca().containers[0],label_type="edge")
plt.show()

# %%
f=a["Club"].value_counts().tail(8)

# %%
f
# Out:
# Club
# Sport Club do Recife    20
# Tromsø IL               20
# Fluminense              20
# Vitória                 20
# Bahia                   20
# Sligo Rovers            19
# Limerick FC             19
# Derry City              18
# Name: count, dtype: int64

# %%
f.plot.bar()
plt.show()

# %%
sns.barplot(x=f.index,y=f.values)
plt.tick_params("x",rotation=90)

# %%
plt.barh(f.index,f.values)
plt.show()

# %%
a.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# ...

# %%
g=a[a["Club"]=="FC Barcelona"]

# %%
round(g.Age.mean())
# Out:
# 24

# %%
barc = a[a['Club']=='FC Barcelona']
round(barc.Age.mean())
# Out:
# 24

# %%
h=a.groupby(a["Club"]=='FC Barcelona').agg({"Age":"mean"})

# %%
h
# Out:
#              Age
# Club
# False  25.097908
# True   23.848485

# %%
a.loc[a["Club"]=='FC Barcelona'].Age.mean()
# Out:
# 23.848484848484848

# %%
round(h)
# Out:
#         Age
# Club
# False  25.0
# True   24.0

# %%
i=a.groupby(a["Club"],as_index=False)["Age"].mean()

# %%
i
# Out:
#                       Club        Age
# 0      SSV Jahn Regensburg  25.655172
# 1    1. FC Heidenheim 1846  24.000000
# 2     1. FC Kaiserslautern  23.846154
# 3               1. FC Köln  24.321429
# 4          1. FC Magdeburg  24.692308
# ..                     ...        ...
# 646     Zagłębie Sosnowiec  26.240000
# 647        Çaykur Rizespor  25.433333
# 648              Örebro SK  24.037037
# 649          Östersunds FK  23.863636
# 650          Śląsk Wrocław  26.166667
#
# [651 rows x 2 columns]

# %%
j=i.sort_values("Age",ascending=True)

# %%
j
# Out:
#                          Club        Age
# 231           FC Nordsjælland  20.259259
# 221              FC Groningen  21.423077
# 83                Bohemian FC  21.480000
# 237    FC Sochaux-Montbéliard  21.678571
# 210  FC Admira Wacker Mödling  21.807692
# ..                        ...        ...
# 64        Atlético Paranaense  30.400000
# 132               Chapecoense  30.400000
# 88                   Botafogo  30.400000
# 168                  Cruzeiro  30.600000
# 433                    Paraná  31.600000
#
# [651 rows x 2 columns]

# %%
j=a.groupby(["Club"])["Age"].mean().sort_values()

# %%
j
# Out:
# Club
# FC Nordsjælland             20.259259
# FC Groningen                21.423077
# Bohemian FC                 21.480000
# FC Sochaux-Montbéliard      21.678571
# FC Admira Wacker Mödling    21.807692
#                               ...
# Atlético Paranaense         30.400000
# Chapecoense                 30.400000
# Botafogo                    30.400000
# Cruzeiro                    30.600000
# Paraná                      31.600000
# Name: Age, Length: 651, dtype: float64

# %%
k=j.sort_values()

# %%
k
# Out:
# Club
# FC Nordsjælland             20.259259
# FC Groningen                21.423077
# Bohemian FC                 21.480000
# FC Sochaux-Montbéliard      21.678571
# FC Admira Wacker Mödling    21.807692
#                               ...
# Chapecoense                 30.400000
# Atlético Paranaense         30.400000
# Botafogo                    30.400000
# Cruzeiro                    30.600000
# Paraná                      31.600000
# Name: Age, Length: 651, dtype: float64

# %%
i=a.groupby(["Club"],as_index=False)["Age"].mean()

# %%
i
# Out:
#                       Club        Age
# 0      SSV Jahn Regensburg  25.655172
# 1    1. FC Heidenheim 1846  24.000000
# 2     1. FC Kaiserslautern  23.846154
# 3               1. FC Köln  24.321429
# 4          1. FC Magdeburg  24.692308
# ..                     ...        ...
# 646     Zagłębie Sosnowiec  26.240000
# 647        Çaykur Rizespor  25.433333
# 648              Örebro SK  24.037037
# 649          Östersunds FK  23.863636
# 650          Śląsk Wrocław  26.166667
#
# [651 rows x 2 columns]

# %%
j=i.Age.sort_values().head(8)

# %%
j
# Out:
# 231    20.259259
# 221    21.423077
# 83     21.480000
# 237    21.678571
# 210    21.807692
# 348    22.000000
# 202    22.035714
# 559    22.074074
# Name: Age, dtype: float64

# %%
a.iloc[j.index]
# Out:
#          ID            Name  Age Nationality  Overall  Potential  \
# 231  230225  Juiano Mestres   34      Brazil       82         82
# 221  156616       F. Ribéry   35      France       83         83
# 83   208421            Saúl   23       Spain       85         90
# 237  221087       Pau López   23       Spain       82         87
# 210  179783     R. Fährmann   29     Germany       83         84
# 348  205923       B. Davies   25       Wales       81         84
# 202  190547         K. Glik   30      Poland       83         83
# 561  231478     L. Martínez   20   Argentina       79         86
#
#                   Club    Value  Wage Preferred Foot  \
# 231           Cruzeiro   6500.0  39.0          Right
# 221  FC Bayern München  11500.0  72.0          Right
# 83     Atlético Madrid  50500.0  77.0           Left
# 237         Real Betis  21500.0  21.0           Left
# 210      FC Schalke 04  20000.0  38.0          Right
# 348  Tottenham Hotspur  18500.0  87.0           Left
# ...

# %%
plt.barh(a.iloc[j.index].Club,j.values )
# Out:
# <BarContainer object of 8 artists>

# %%
a.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# ...

# %%
highest_wages=a["Wage"].sort_values(ascending=False).head(10)

# %%
highest_wages
# Out:
# 0     565.0
# 7     455.0
# 6     420.0
# 1     405.0
# 8     380.0
# 36    355.0
# 11    355.0
# 4     355.0
# 5     340.0
# 32    340.0
# Name: Wage, dtype: float64

# %%
a.loc[highest_wages.index]
# Out:
#         ID               Name  Age Nationality  Overall  Potential  \
# 0   158023           L. Messi   31   Argentina       94         94
# 7   176580          L. Suárez   31     Uruguay       91         91
# 6   177003          L. Modrić   32     Croatia       91         91
# 1    20801  Cristiano Ronaldo   33    Portugal       94         94
# 8   155862       Sergio Ramos   32       Spain       91         91
# 36  173731            G. Bale   28       Wales       88         88
# 11  182521           T. Kroos   28     Germany       90         90
# 4   192985       K. De Bruyne   27     Belgium       91         92
# 5   183277          E. Hazard   27     Belgium       91         91
# 32  189242           Coutinho   26      Brazil       88         89
#
#                Club     Value   Wage Preferred Foot  International Reputation  \
# 0      FC Barcelona  110500.0  565.0           Left                       5.0
# ...

# %%
plt.barh(a.iloc[highest_wages.index].Name,highest_wages.values)
plt.show()

# %%
plt.plot(highest_wages.values,a.iloc[highest_wages.index].Name)

# %%
a.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# ...

# %%
lowest_wages=a["Wage"].sort_values().head(10)

# %%
lowest_wages
# Out:
# 9104     1.0
# 13433    1.0
# 13435    1.0
# 13436    1.0
# 13438    1.0
# 13440    1.0
# 13441    1.0
# 13432    1.0
# 13442    1.0
# 13444    1.0
# Name: Wage, dtype: float64

# %%
lowest_wages.plot.barh()
plt.show()

# %%
plt.barh(a.loc[lowest_wages.index].Name,lowest_wages.values)
plt.show()

# %%
a.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# ...

# %%
p=a["Preferred Foot"].value_counts()

# %%
p.plot.bar()
plt.show()

# %%
sns.countplot(a["Preferred Foot"],color="orange")
# Out:
# <Axes: xlabel='count', ylabel='Preferred Foot'>

# %%
a.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# ...

# %%
tallest=a["Height"].sort_values(ascending=False).head(10)

# %%
tallest
# Out:
# 11614    6.750000
# 17927    6.750000
# 4281     6.666667
# 16923    6.666667
# 17920    6.666667
# 11403    6.666667
# 4189     6.666667
# 17694    6.666667
# 14542    6.666667
# 9559     6.666667
# Name: Height, dtype: float64

# %%
a.loc[tallest.index]
# Out:
#            ID                 Name  Age     Nationality  Overall  Potential  \
# 11614  199321              T. Holý   26  Czech Republic       64         68
# 17927  243796            D. Hodzic   22         Croatia       51         61
# 4281   192613        C. Pantilimon   31         Romania       71         71
# 16923  243387            S. Brolin   17          Sweden       56         78
# 17920  237127             D. Thiam   20         Senegal       51         66
# 11403  218212           A. Noppert   24     Netherlands       64         69
# 4189   224836  V. Milinković-Savić   21          Serbia       71         79
# 17694  241870             M. Casey   18         England       53         73
# 14542  237015             M. Qvist   25         Denmark       61         64
# 9559   243628           A. Vukotić   22          Serbia       66         72
#
#                     Club   Value  Wage Preferred Foot  \
# 11614         Gillingham   400.0   2.0          Right
# ...

# %%
a.iloc[highest_wages.index].Name
# Out:
# 0              L. Messi
# 7             L. Suárez
# 6             L. Modrić
# 1     Cristiano Ronaldo
# 8          Sergio Ramos
# 36              G. Bale
# 11             T. Kroos
# 4          K. De Bruyne
# 5             E. Hazard
# 32             Coutinho
# Name: Name, dtype: object

# %%
plt.barh(a.loc[tallest.index].Name,tallest.values)
# Out:
# <BarContainer object of 10 artists>

# %%
a.loc[tallest.index].Name
# Out:
# 11614                T. Holý
# 17927              D. Hodzic
# 4281           C. Pantilimon
# 16923              S. Brolin
# 17920               D. Thiam
# 11403             A. Noppert
# 4189     V. Milinković-Savić
# 17694               M. Casey
# 14542               M. Qvist
# 9559              A. Vukotić
# Name: Name, dtype: object

# %%
a.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# ...

# %%
shortest_players=a["Height"].sort_values().head(10)

# %%
shortest_players
# Out:
# 6584     5.083333
# 6275     5.083333
# 17157    5.083333
# 2768     5.166667
# 2493     5.166667
# 5828     5.166667
# 8536     5.166667
# 1340     5.166667
# 7126     5.250000
# 5620     5.250000
# Name: Height, dtype: float64

# %%
a.loc[shortest_players.index]
# Out:
#            ID           Name  Age Nationality  Overall  Potential  \
# 6584   232951    H. Nakagawa   23       Japan       69         72
# 6275   237994     N. Barrios   20   Argentina       69         82
# 17157  242566   K. Yamaguchi   23       Japan       55         61
# 2768   159818          Élton   32      Brazil       73         73
# 2493   202184       J. Plata   26     Ecuador       74         74
# 5828   228404     C. Techera   26     Uruguay       69         70
# 8536   234698  C. Songkrasin   24    Thailand       67         70
# 1340   183895     M. Moralez   31   Argentina       76         76
# 7126   225150      A. Araujo   21    Portugal       68         75
# 5620   222970     E. Oztumer   27     England       70         71
#
#                              Club   Value  Wage Preferred Foot  \
# 6584               Kashiwa Reysol  1300.0   5.0          Right
# 6275       San Lorenzo de Almagro  2000.0   7.0          Right
# ...

# %%
shortest_players.plot.bar()

plt.show()

# %%
plt.bar(a.loc[shortest_players.index].Name,shortest_players.values)
plt.xticks(rotation="vertical")
plt.show()

# %%
plt.barh(a.loc[shortest_players.index].Name,shortest_players.values)
plt.show()

# %%
f=pd.concat([tallest,shortest_players])

# %%
f
# Out:
# 11614    6.750000
# 17927    6.750000
# 4281     6.666667
# 16923    6.666667
# 17920    6.666667
# 11403    6.666667
# 4189     6.666667
# 17694    6.666667
# 14542    6.666667
# 9559     6.666667
# 6584     5.083333
# 6275     5.083333
# 17157    5.083333
# 2768     5.166667
# 2493     5.166667
# 5828     5.166667
# 8536     5.166667
# 1340     5.166667
# 7126     5.250000
# 5620     5.250000
# Name: Height, dtype: float64

# %%
s=f=pd.concat([tallest,shortest_players],axis=1)

# %%
s
# Out:
#          Height    Height
# 11614  6.750000       NaN
# 17927  6.750000       NaN
# 4281   6.666667       NaN
# 16923  6.666667       NaN
# 17920  6.666667       NaN
# 11403  6.666667       NaN
# 4189   6.666667       NaN
# 17694  6.666667       NaN
# 14542  6.666667       NaN
# 9559   6.666667       NaN
# 6584        NaN  5.083333
# 6275        NaN  5.083333
# 17157       NaN  5.083333
# 2768        NaN  5.166667
# 2493        NaN  5.166667
# 5828        NaN  5.166667
# 8536        NaN  5.166667
# 1340        NaN  5.166667
# 7126        NaN  5.250000
# 5620        NaN  5.250000

# %%
v=f=pd.concat([tallest,shortest_players]).reset_index()

# %%
v
# Out:
#     index    Height
# 0   11614  6.750000
# 1   17927  6.750000
# 2    4281  6.666667
# 3   16923  6.666667
# 4   17920  6.666667
# 5   11403  6.666667
# 6    4189  6.666667
# 7   17694  6.666667
# 8   14542  6.666667
# 9    9559  6.666667
# 10   6584  5.083333
# 11   6275  5.083333
# 12  17157  5.083333
# 13   2768  5.166667
# 14   2493  5.166667
# 15   5828  5.166667
# 16   8536  5.166667
# 17   1340  5.166667
# 18   7126  5.250000
# 19   5620  5.250000

# %%
q=v[:10]

# %%
r=v[10:]

# %%
q
# Out:
#    index    Height
# 0  11614  6.750000
# 1  17927  6.750000
# 2   4281  6.666667
# 3  16923  6.666667
# 4  17920  6.666667
# 5  11403  6.666667
# 6   4189  6.666667
# 7  17694  6.666667
# 8  14542  6.666667
# 9   9559  6.666667

# %%
d=[q,r]

# %%
d
# Out:
# [   index    Height
#  0  11614  6.750000
#  1  17927  6.750000
#  2   4281  6.666667
#  3  16923  6.666667
#  4  17920  6.666667
#  5  11403  6.666667
#  6   4189  6.666667
#  7  17694  6.666667
#  8  14542  6.666667
#  9   9559  6.666667,
#      index    Height
#  10   6584  5.083333
#  11   6275  5.083333
#  12  17157  5.083333
#  13   2768  5.166667
#  14   2493  5.166667
#  15   5828  5.166667
#  16   8536  5.166667
#  17   1340  5.166667
#  18   7126  5.250000
#  19   5620  5.250000]

# %%
d=pd.concat(d,axis=1)

# %%
d
# Out:
#       index    Height    index    Height
# 0   11614.0  6.750000      NaN       NaN
# 1   17927.0  6.750000      NaN       NaN
# 2    4281.0  6.666667      NaN       NaN
# 3   16923.0  6.666667      NaN       NaN
# 4   17920.0  6.666667      NaN       NaN
# 5   11403.0  6.666667      NaN       NaN
# 6    4189.0  6.666667      NaN       NaN
# 7   17694.0  6.666667      NaN       NaN
# 8   14542.0  6.666667      NaN       NaN
# 9    9559.0  6.666667      NaN       NaN
# 10      NaN       NaN   6584.0  5.083333
# 11      NaN       NaN   6275.0  5.083333
# 12      NaN       NaN  17157.0  5.083333
# 13      NaN       NaN   2768.0  5.166667
# 14      NaN       NaN   2493.0  5.166667
# 15      NaN       NaN   5828.0  5.166667
# 16      NaN       NaN   8536.0  5.166667
# 17      NaN       NaN   1340.0  5.166667
# 18      NaN       NaN   7126.0  5.250000
# 19      NaN       NaN   5620.0  5.250000

# %%
d.columns=["index_tallest","height(tallest)","index_Shortest","height(shortest)"]

# %%
d
# Out:
#     index_tallest  height(tallest)  index_Shortest  height(shortest)
# 0         11614.0         6.750000             NaN               NaN
# 1         17927.0         6.750000             NaN               NaN
# 2          4281.0         6.666667             NaN               NaN
# 3         16923.0         6.666667             NaN               NaN
# 4         17920.0         6.666667             NaN               NaN
# 5         11403.0         6.666667             NaN               NaN
# 6          4189.0         6.666667             NaN               NaN
# 7         17694.0         6.666667             NaN               NaN
# 8         14542.0         6.666667             NaN               NaN
# 9          9559.0         6.666667             NaN               NaN
# 10            NaN              NaN          6584.0          5.083333
# 11            NaN              NaN          6275.0          5.083333
# 12            NaN              NaN         17157.0          5.083333
# ...

# %%
d.plot.bar()
plt.show()

# %%
s=pd.concat([tallest,shortest_players])

# %%
s
# Out:
# 11614    6.750000
# 17927    6.750000
# 4281     6.666667
# 16923    6.666667
# 17920    6.666667
# 11403    6.666667
# 4189     6.666667
# 17694    6.666667
# 14542    6.666667
# 9559     6.666667
# 6584     5.083333
# 6275     5.083333
# 17157    5.083333
# 2768     5.166667
# 2493     5.166667
# 5828     5.166667
# 8536     5.166667
# 1340     5.166667
# 7126     5.250000
# 5620     5.250000
# Name: Height, dtype: float64

# %%
s.plot.bar()
plt.show()

# %%
plt.barh(a.loc[s.index].Name,s.values)
plt.show()

# %%
a.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# ...

# %%
wage=a.groupby(["Club"],as_index=False)["Wage"].sum()

# %%
wage
# Out:
#                       Club   Wage
# 0      SSV Jahn Regensburg  123.0
# 1    1. FC Heidenheim 1846  125.0
# 2     1. FC Kaiserslautern   44.0
# 3               1. FC Köln  372.0
# 4          1. FC Magdeburg  127.0
# ..                     ...    ...
# 646     Zagłębie Sosnowiec   27.0
# 647        Çaykur Rizespor  193.0
# 648              Örebro SK   40.0
# 649          Östersunds FK   45.0
# 650          Śląsk Wrocław   50.0
#
# [651 rows x 2 columns]

# %%
v
# Out:
#     index    Height
# 0   11614  6.750000
# 1   17927  6.750000
# 2    4281  6.666667
# 3   16923  6.666667
# 4   17920  6.666667
# 5   11403  6.666667
# 6    4189  6.666667
# 7   17694  6.666667
# 8   14542  6.666667
# 9    9559  6.666667
# 10   6584  5.083333
# 11   6275  5.083333
# 12  17157  5.083333
# 13   2768  5.166667
# 14   2493  5.166667
# 15   5828  5.166667
# 16   8536  5.166667
# 17   1340  5.166667
# 18   7126  5.250000
# 19   5620  5.250000

# %%
plt.barh(a.loc[v.index].Name,v.Height)
plt.show()

# %%
wage
# Out:
#                       Club   Wage
# 0      SSV Jahn Regensburg  123.0
# 1    1. FC Heidenheim 1846  125.0
# 2     1. FC Kaiserslautern   44.0
# 3               1. FC Köln  372.0
# 4          1. FC Magdeburg  127.0
# ..                     ...    ...
# 646     Zagłębie Sosnowiec   27.0
# 647        Çaykur Rizespor  193.0
# 648              Örebro SK   40.0
# 649          Östersunds FK   45.0
# 650          Śląsk Wrocław   50.0
#
# [651 rows x 2 columns]

# %%
wage=wage.Wage.mean()

# %%
wage
# Out:
# 271.9815668202765

# %%
a.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# ...

# %%
wages=a.groupby(["Club"],as_index=False)["Wage"].mean()

# %%
wages
# Out:
#                       Club       Wage
# 0      SSV Jahn Regensburg   4.241379
# 1    1. FC Heidenheim 1846   4.464286
# 2     1. FC Kaiserslautern   1.692308
# 3               1. FC Köln  13.285714
# 4          1. FC Magdeburg   4.884615
# ..                     ...        ...
# 646     Zagłębie Sosnowiec   1.080000
# 647        Çaykur Rizespor   6.433333
# 648              Örebro SK   1.481481
# 649          Östersunds FK   2.045455
# 650          Śląsk Wrocław   2.083333
#
# [651 rows x 2 columns]

# %%
a.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# ...

# %%
left=a["Preferred Foot"]=="Left"

# %%
left
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18202    False
# 18203    False
# 18204    False
# 18205    False
# 18206    False
# Name: Preferred Foot, Length: 17907, dtype: bool

# %%
a.loc[left]
# Out:
#            ID                  Name  Age          Nationality  Overall  \
# 0      158023              L. Messi   31            Argentina       94
# 13     168542           David Silva   32                Spain       90
# 15     211110             P. Dybala   24            Argentina       89
# 17     194765          A. Griezmann   27               France       89
# 19     192119           T. Courtois   26              Belgium       89
# ...       ...                   ...  ...                  ...      ...
# 18172  243636            C. Hawkins   18              England       48
# 18175  243649             E. Clarke   19              England       48
# 18191  245570  J. Norville-Williams   18              England       47
# 18200  231381              J. Young   18             Scotland       47
# 18201  243413              D. Walsh   18  Republic of Ireland       47
#
#        Potential              Club     Value   Wage Preferred Foot  \
# ...

# %%
a.loc[left].shape
# Out:
# (4159, 18)

# %%
a.reset_index()
# Out:
#        index      ID                Name  Age Nationality  Overall  Potential  \
# 0          0  158023            L. Messi   31   Argentina       94         94
# 1          1   20801   Cristiano Ronaldo   33    Portugal       94         94
# 2          2  190871           Neymar Jr   26      Brazil       92         93
# 3          3  193080              De Gea   27       Spain       91         93
# 4          4  192985        K. De Bruyne   27     Belgium       91         92
# ...      ...     ...                 ...  ...         ...      ...        ...
# 17902  18202  238813        J. Lundstram   19     England       47         65
# 17903  18203  243165  N. Christoffersson   19      Sweden       47         63
# 17904  18204  241638           B. Worman   16     England       47         67
# 17905  18205  246268      D. Walker-Rice   17     England       47         66
# 17906  18206  246269           G. Nugent   16     England       46         66
#
# ...

# %%
left.value_counts()
# Out:
# Preferred Foot
# False    13748
# True      4159
# Name: count, dtype: int64

# %%
left=a[a["Preferred Foot"]=="Left"]

# %%
left
# Out:
#            ID                  Name  Age          Nationality  Overall  \
# 0      158023              L. Messi   31            Argentina       94
# 13     168542           David Silva   32                Spain       90
# 15     211110             P. Dybala   24            Argentina       89
# 17     194765          A. Griezmann   27               France       89
# 19     192119           T. Courtois   26              Belgium       89
# ...       ...                   ...  ...                  ...      ...
# 18172  243636            C. Hawkins   18              England       48
# 18175  243649             E. Clarke   19              England       48
# 18191  245570  J. Norville-Williams   18              England       47
# 18200  231381              J. Young   18             Scotland       47
# 18201  243413              D. Walsh   18  Republic of Ireland       47
#
#        Potential              Club     Value   Wage Preferred Foot  \
# ...

# %%
left
# Out:
#            ID                  Name  Age          Nationality  Overall  \
# 0      158023              L. Messi   31            Argentina       94
# 13     168542           David Silva   32                Spain       90
# 15     211110             P. Dybala   24            Argentina       89
# 17     194765          A. Griezmann   27               France       89
# 19     192119           T. Courtois   26              Belgium       89
# ...       ...                   ...  ...                  ...      ...
# 18172  243636            C. Hawkins   18              England       48
# 18175  243649             E. Clarke   19              England       48
# 18191  245570  J. Norville-Williams   18              England       47
# 18200  231381              J. Young   18             Scotland       47
# 18201  243413              D. Walsh   18  Republic of Ireland       47
#
#        Potential              Club     Value   Wage Preferred Foot  \
# ...

# %%
left=left.head(8)

# %%
left=left.Club.value_counts()

# %%
plt.barh(left.index,left.values)
plt.show()

# %%
tail=a[a["Preferred Foot"]=="Left"]

# %%
tail
# Out:
#            ID                  Name  Age          Nationality  Overall  \
# 0      158023              L. Messi   31            Argentina       94
# 13     168542           David Silva   32                Spain       90
# 15     211110             P. Dybala   24            Argentina       89
# 17     194765          A. Griezmann   27               France       89
# 19     192119           T. Courtois   26              Belgium       89
# ...       ...                   ...  ...                  ...      ...
# 18172  243636            C. Hawkins   18              England       48
# 18175  243649             E. Clarke   19              England       48
# 18191  245570  J. Norville-Williams   18              England       47
# 18200  231381              J. Young   18             Scotland       47
# 18201  243413              D. Walsh   18  Republic of Ireland       47
#
#        Potential              Club     Value   Wage Preferred Foot  \
# ...

# %%
tail=tail.Club.value_counts()

# %%
tail=tail.tail(8)

# %%
tail
# Out:
# Club
# New England Revolution        2
# Unión La Calera               2
# BK Häcken                     2
# Gamba Osaka                   2
# Beijing Sinobo Guoan FC       2
# Guizhou Hengfeng FC           2
# GFC Ajaccio                   2
# Shandong Luneng TaiShan FC    1
# Name: count, dtype: int64

# %%
plt.barh(tail.index,tail.values)
plt.show()

# %%
a.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# ...

# %%
right=a["Preferred Foot"]=="Right"

# %%
right
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 18202     True
# 18203     True
# 18204     True
# 18205     True
# 18206     True
# Name: Preferred Foot, Length: 17907, dtype: bool

# %%
a.loc[right]
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# 5      183277           E. Hazard   27     Belgium       91         91
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
right=a[a["Preferred Foot"]=="Right"]

# %%
right
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# 5      183277           E. Hazard   27     Belgium       91         91
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
k=right.Club.value_counts()

# %%
k=k.head(9)

# %%
k
# Out:
# Club
# Chelsea                29
# Gamba Osaka            28
# TSG 1899 Hoffenheim    28
# Southampton            28
# V-Varen Nagasaki       28
# Liverpool              27
# Montreal Impact        27
# Fenerbahçe SK          27
# Real Salt Lake         27
# Name: count, dtype: int64

# %%
k.plot.barh()
plt.show()

# %%
plt.barh(k.index,k.values)
plt.show()

# %%
t=right.Club.value_counts().tail(8)

# %%
t
# Out:
# Club
# Botafogo               13
# Tromsø IL              13
# Bahia                  13
# Internacional          12
# Atlético Mineiro       12
# Atlético Paranaense    12
# Derry City             11
# Vitória                10
# Name: count, dtype: int64

# %%
t.plot.bar()
plt.show()

# %%
plt.barh(t.index,t.values)
plt.show()

# %%
a.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# ...

# %%
inter=a["International Reputation"].value_counts()

# %%
inter
# Out:
# International Reputation
# 1.0    16298
# 2.0     1245
# 3.0      307
# 4.0       51
# 5.0        6
# Name: count, dtype: int64

# %%
a["International Reputation"]=a["International Reputation"].astype("int64")

# %%
a.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                         5          4.0       RF    2004
# 1                         5          5.0       ST    2018
# ...

# %%
a.dtypes
# Out:
# ID                            int64
# Name                         object
# Age                           int64
# Nationality                  object
# Overall                       int64
# Potential                     int64
# Club                         object
# Value                       float64
# Wage                        float64
# Preferred Foot               object
# International Reputation      int64
# Skill Moves                 float64
# Position                     object
# Joined                        int64
# Contract Valid Until         object
# Height                      float64
# Weight                      float64
# Release Clause              float64
# dtype: object

# %%
a.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                         5          4.0       RF    2004
# 1                         5          5.0       ST    2018
# ...

# %%
high=a[a["International Reputation"]==5]

# %%
high
# Out:
#          ID               Name  Age Nationality  Overall  Potential  \
# 0    158023           L. Messi   31   Argentina       94         94
# 1     20801  Cristiano Ronaldo   33    Portugal       94         94
# 2    190871          Neymar Jr   26      Brazil       92         93
# 7    176580          L. Suárez   31     Uruguay       91         91
# 22   167495           M. Neuer   32     Germany       89         89
# 109   41236     Z. Ibrahimović   36      Sweden       85         85
#
#                     Club     Value   Wage Preferred Foot  \
# 0           FC Barcelona  110500.0  565.0           Left
# 1               Juventus   77000.0  405.0          Right
# 2    Paris Saint-Germain  118500.0  290.0          Right
# 7           FC Barcelona   80000.0  455.0          Right
# 22     FC Bayern München   38000.0  130.0          Right
# 109            LA Galaxy   14000.0   15.0          Right
#
#      International Reputation  Skill Moves Position  Joined  \
# ...

# %%
print("hi")
# Out:
# hi

# %%
print("hello")
# Out:
# hello

# %%
plt.barh(high["Name"],high["Potential"])
plt.show()

# %%
from wordcloud import WordCloud

# %%
s=" ".join(i  for i in a.Name)
f=WordCloud(background_color="black").generate(s)

plt.figure(figsize=(15,6))
plt.imshow(f)
plt.axis("off")
plt.show()

# %%
s=" ".join(i  for i in a.Name)
f=WordCloud(background_color="black").generate(s)

plt.figure(figsize=(15,6))
plt.imshow(f,interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
a.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                         5          4.0       RF    2004
# 1                         5          5.0       ST    2018
# ...

# %%
a["Position"].unique()
# Out:
# array(['RF', 'ST', 'LW', 'GK', 'RCM', 'LF', 'RS', 'RCB', 'LCM', 'CB',
#        'LDM', 'CAM', 'CDM', 'LS', 'LCB', 'RM', 'LAM', 'LM', 'LB', 'RDM',
#        'RW', 'CM', 'RB', 'RAM', 'CF', 'RWB', 'LWB'], dtype=object)

# %%
avg=a.groupby(["Club"],as_index=False)["International Reputation"].mean()

# %%
avg
# Out:
#                       Club  International Reputation
# 0      SSV Jahn Regensburg                  1.000000
# 1    1. FC Heidenheim 1846                  1.000000
# 2     1. FC Kaiserslautern                  1.000000
# 3               1. FC Köln                  1.321429
# 4          1. FC Magdeburg                  1.038462
# ..                     ...                       ...
# 646     Zagłębie Sosnowiec                  1.000000
# 647        Çaykur Rizespor                  1.000000
# 648              Örebro SK                  1.000000
# 649          Östersunds FK                  1.000000
# 650          Śląsk Wrocław                  1.000000
#
# [651 rows x 2 columns]

# %%
k=avg.sort_values("International Reputation",ascending=0)

# %%
k=k.head(10)

# %%
k
# Out:
#                     Club  International Reputation
# 326             Juventus                  2.520000
# 214    FC Bayern München                  2.517241
# 212         FC Barcelona                  2.242424
# 435  Paris Saint-Germain                  2.233333
# 315                Inter                  2.166667
# 398               Napoli                  2.160000
# 134              Chelsea                  2.121212
# 382                Milan                  2.111111
# 470          Real Madrid                  2.090909
# 375    Manchester United                  2.090909

# %%
plt.barh(k["Club"],k["International Reputation"])
plt.show()

# %%
k.plot.bar()
plt.show()

# %%
j=k["International Reputation"].sort_values(ascending=False).head(10)

# %%
j
# Out:
# 326    2.520000
# 214    2.517241
# 212    2.242424
# 435    2.233333
# 315    2.166667
# 398    2.160000
# 134    2.121212
# 382    2.111111
# 470    2.090909
# 375    2.090909
# Name: International Reputation, dtype: float64

# %%
plt.barh(a.iloc[j.index].Name,j.values)
plt.show()

# %%
a.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                         5          4.0       RF    2004
# 1                         5          5.0       ST    2018
# ...

# %%
position=a["Position"].value_counts()

# %%
position
# Out:
# Position
# ST     2130
# GK     1989
# CB     1751
# CM     1377
# LB     1304
# RB     1268
# RM     1114
# LM     1086
# CAM     946
# CDM     936
# RCB     652
# LCB     635
# LCM     389
# RCM     387
# LW      374
# RW      365
# RDM     246
# LDM     239
# LS      206
# RS      201
# RWB      87
# LWB      78
# CF       74
# LAM      21
# RAM      21
# RF       16
# LF       15
# Name: count, dtype: int64

# %%
plt.barh(position.index,position.values)
# Out:
# <BarContainer object of 27 artists>
